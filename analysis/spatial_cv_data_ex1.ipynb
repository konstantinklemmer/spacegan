# %% [markdown]
# ## Setup
#
# Load required packages

# %%
import pandas as pd
import io
import requests
import numpy as np
import random
import libpysal
import pysal
# Out:
# C:\Users\kklemmer\AppData\Local\Continuum\anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# Read data

# %%
#Read from URL (Doesnt work for private repos)
#url="https://github.com/konstantinklemmer/spacegan/raw/master/data/synth_data.csv"
#s=requests.get(url).content
#data=pd.read_csv(io.StringIO(s.decode('utf-8')))

#Read from local file
data=pd.read_csv("./raw_data/synth_data_ex1.csv")

# %%
data.head(5)
# Out:
#    id         y         z  latitude  longitude
# 0   1 -0.844504  1.370958       2.5        2.5
# 1   2 -0.832568 -0.564698       2.5        7.5
# 2   3 -0.793995  0.363128       2.5       12.5
# 3   4 -0.730340  0.632863       2.5       17.5
# 4   5 -0.641493  0.404268       2.5       22.5

# %% [markdown]
# Create a pairwise distance matrix (Euclidean) between the points

# %%
dist = pysal.lib.cg.distance_matrix(np.array(data[["longitude","latitude"]]))

# %% [markdown]
# Get the `k` smallest distances (of the whole matrix, since the points are equally distributed)

# %%
k=10
u_dist = np.unique(dist)
k_min_dist = np.sort(u_dist.flatten())[:k]

# %%
k_min_dist
# Out:
# array([ 0.        ,  5.        ,  7.07106781, 10.        , 11.18033989,
#        14.14213562, 15.        , 15.8113883 , 18.02775638, 20.        ])

# %% [markdown]
# Create spatial points object ([KDTree](https://pysal.readthedocs.io/en/dev/library/cg/kdtree.html))).

# %%
import pysal.lib
kd = pysal.lib.cg.kdtree.KDTree(np.array(data[["longitude","latitude"]]))

# %%
kd

# %% [markdown]
# Compute spatial neighbourhoods weight matrix by distance threshold ("radius")

# %%
#wnn = pysal.lib.weights.KNN(kd, 8, ids=data["id"]) #KNN based weights
#wdist= pysal.lib.weights.distance.DistanceBand(kd, threshold=k_min_dist[1],binary=False,p=2) #Rook
wdist= pysal.lib.weights.distance.DistanceBand(kd, threshold=k_min_dist[2],binary=True,p=2) #Queen
#wdist= pysal.lib.weights.distance.DistanceBand(kd, threshold=k_min_dist[4],binary=True,p=2) #Queen 2nd degree

# %% [markdown]
# ## Spatial CV: Lat/Lon slicing

# %% [markdown]
# Create labels based on latitude / longitude binning and add the labels to the original data

# %%
data["lon_group"] = pd.cut(data["longitude"],bins=5,labels=[1,2,3,4,5])
data["lat_group"] = pd.cut(data["latitude"],bins=5,labels=[1,2,3,4,5])

# %% [markdown]
# This method loops over our lat/lon groups, keeping each group as test data and the rest as train data. However, as we want to do spatial cross-validation, we remove neighbors of the test set. This can help to prevent model overfitting. Here, we remove 1st and 2nd degree neighbors, but the method can be adapted as needed. We create 10 folds (5 lon, 5 lat slicing) and save these in the columns `lat_group[1-5]` and `lon_group[1-5]`. For the values in each of these columns, `1` indicates testing data, `2` training data and `0`indicates data to be removed.

# %%
for q in list(data)[-2::]: #Loop over the two slicing label columns 
    data["s_id"] = data[q] #Define which label column to use for slicing
    
    for j in np.unique(data["s_id"]): #Loop over the unique labels in the slicing column 
        
        data[q+str(j)] = 0
        
        test = data[data["s_id"]==j] #Define test data 
        data.loc[data["id"].isin(np.array(test["id"])),q+str(j)] = 1
        
        temp_id = [] #Create empty neighbourhood index
        
        for k in test.index: #Fill neighborhood index using first degree neighbors of test data
            temp_id = np.unique(np.concatenate([temp_id,wdist.neighbors[k]]).ravel().astype(np.int32))
            
        for l in temp_id: #Include second degree neighbors
            temp_id = np.unique(np.concatenate([temp_id,wdist.neighbors[l]]).ravel().astype(np.int32))
        
        #for m in temp_id: #Include third degree neighbors
        #    temp_id = np.unique(np.concatenate([temp_id,wdist.neighbors[m]]).ravel().astype(np.int32))
            
        train = data[data["s_id"]!=j] #Define train data 
        train = train.drop(temp_id,errors="ignore") #Exclude neighbors from index
        data.loc[data["id"].isin(np.array(train["id"])),q+str(j)] = 2

#Drop helper columns
data = data.drop(columns=["lon_group","lat_group","s_id"])

# %% [markdown]
# Rename columns to represent cross-validation folds

# %%
data.rename(columns=dict(zip(data.filter(regex='_group').columns,
                             ["fold1","fold2","fold3","fold4","fold5","fold6","fold7","fold8","fold9","fold10"])),
            inplace=True)

# %%
data
# Out:
#       id         y         z  latitude  longitude  fold1  fold2  fold3  fold4  \
# 0      1 -0.844504  1.370958       2.5        2.5      1      2      2      2
# 1      2 -0.832568 -0.564698       2.5        7.5      1      2      2      2
# 2      3 -0.793995  0.363128       2.5       12.5      1      0      2      2
# 3      4 -0.730340  0.632863       2.5       17.5      1      0      2      2
# 4      5 -0.641493  0.404268       2.5       22.5      0      1      2      2
# 5      6 -0.527385 -0.106125       2.5       27.5      0      1      2      2
# 6      7 -0.387048  1.511522       2.5       32.5      2      1      0      2
# 7      8 -0.222415 -0.094659       2.5       37.5      2      1      0      2
# 8      9 -0.031306  2.018424       2.5       42.5      2      0      1      2
# 9     10  0.184221 -0.062714       2.5       47.5      2      0      1      2
# 10    11  0.426173  1.304870       2.5       52.5      2      2      1      0
# 11    12  0.692910  2.286645       2.5       57.5      2      2      1      0
# 12    13  0.984285 -1.388861       2.5       62.5      2      2      0      1
# 13    14  1.302316 -0.278789       2.5       67.5      2      2      0      1
# 14    15  1.645473 -0.133321       2.5       72.5      2      2      2      1
# 15    16  2.014341  0.635950       2.5       77.5      2      2      2      1
# 16    17  2.407809 -0.284253       2.5       82.5      2      2      2      0
# 17    18  2.827041 -2.656455       2.5       87.5      2      2      2      0
# 18    19  3.271690 -2.440467       2.5       92.5      2      2      2      2
# 19    20  3.742664  1.320113       2.5       97.5      2      2      2      2
# 20    21 -0.832449 -0.306639       7.5        2.5      1      2      2      2
# 21    22 -0.845500 -1.781308       7.5        7.5      1      2      2      2
# 22    23 -0.832383 -0.171917       7.5       12.5      1      0      2      2
# 23    24 -0.793699  1.214675       7.5       17.5      1      0      2      2
# 24    25 -0.730159  1.895193       7.5       22.5      0      1      2      2
# 25    26 -0.641905 -0.430469       7.5       27.5      0      1      2      2
# 26    27 -0.527461 -0.257269       7.5       32.5      2      1      0      2
# 27    28 -0.388055 -1.763163       7.5       37.5      2      1      0      2
# 28    29 -0.222141  0.460097       7.5       42.5      2      0      1      2
# 29    30 -0.032067 -0.639995       7.5       47.5      2      0      1      2
# ..   ...       ...       ...       ...        ...    ...    ...    ...    ...
# 370  371 -0.031256  1.628442      92.5       52.5      2      2      1      0
# 371  372 -0.222322  0.088522      92.5       57.5      2      2      1      0
# 372  373 -0.387075  1.239151      92.5       62.5      2      2      0      1
# 373  374 -0.527838 -1.644556      92.5       67.5      2      2      0      1
# 374  375 -0.641189  1.446357      92.5       72.5      2      2      2      1
# 375  376 -0.730965 -0.690560      92.5       77.5      2      2      2      1
# 376  377 -0.794314 -0.276431      92.5       82.5      2      2      2      0
# 377  378 -0.832751 -1.109419      92.5       87.5      2      2      2      0
# 378  379 -0.844935  0.133869      92.5       92.5      2      2      2      2
# 379  380 -0.831799  1.785339      92.5       97.5      2      2      2      2
# 380  381  3.742507  2.422163      97.5        2.5      1      2      2      2
# 381  382  3.271571 -1.076829      97.5        7.5      1      2      2      2
# 382  383  2.827516  0.485941      97.5       12.5      1      0      2      2
# 383  384  2.408452  1.388522      97.5       17.5      1      0      2      2
# 384  385  2.013941 -0.195657      97.5       22.5      0      1      2      2
# 385  386  1.645431 -0.218175      97.5       27.5      0      1      2      2
# 386  387  1.302303 -0.304778      97.5       32.5      2      1      0      2
# 387  388  0.985070  0.597833      97.5       37.5      2      1      0      2
# 388  389  0.693027  1.397429      97.5       42.5      2      0      1      2
# 389  390  0.426005  0.687620      97.5       47.5      2      0      1      2
# 390  391  0.184413  0.320188      97.5       52.5      2      2      1      0
# 391  392 -0.031915 -0.301870      97.5       57.5      2      2      1      0
# 392  393 -0.222124  0.498349      97.5       62.5      2      2      0      1
# 393  394 -0.387821 -0.549537      97.5       67.5      2      2      0      1
# 394  395 -0.527471 -0.279257      97.5       72.5      2      2      2      1
# 395  396 -0.641241  1.096513      97.5       77.5      2      2      2      1
# 396  397 -0.730423  0.442013      97.5       82.5      2      2      2      0
# 397  398 -0.794054  0.241016      97.5       87.5      2      2      2      0
# 398  399 -0.832424 -0.255608      97.5       92.5      2      2      2      2
# 399  400 -0.844595  0.931033      97.5       97.5      2      2      2      2
#
#      fold5  fold6  fold7  fold8  fold9  fold10
# 0        2      1      2      2      2       2
# 1        2      1      2      2      2       2
# 2        2      1      2      2      2       2
# 3        2      1      2      2      2       2
# 4        2      1      2      2      2       2
# 5        2      1      2      2      2       2
# 6        2      1      2      2      2       2
# 7        2      1      2      2      2       2
# 8        2      1      2      2      2       2
# 9        2      1      2      2      2       2
# 10       2      1      2      2      2       2
# 11       2      1      2      2      2       2
# 12       2      1      2      2      2       2
# 13       2      1      2      2      2       2
# 14       0      1      2      2      2       2
# 15       0      1      2      2      2       2
# 16       1      1      2      2      2       2
# 17       1      1      2      2      2       2
# 18       1      1      2      2      2       2
# 19       1      1      2      2      2       2
# 20       2      1      2      2      2       2
# 21       2      1      2      2      2       2
# 22       2      1      2      2      2       2
# 23       2      1      2      2      2       2
# 24       2      1      2      2      2       2
# 25       2      1      2      2      2       2
# 26       2      1      2      2      2       2
# 27       2      1      2      2      2       2
# 28       2      1      2      2      2       2
# 29       2      1      2      2      2       2
# ..     ...    ...    ...    ...    ...     ...
# 370      2      2      2      2      2       1
# 371      2      2      2      2      2       1
# 372      2      2      2      2      2       1
# 373      2      2      2      2      2       1
# 374      0      2      2      2      2       1
# 375      0      2      2      2      2       1
# 376      1      2      2      2      2       1
# 377      1      2      2      2      2       1
# 378      1      2      2      2      2       1
# 379      1      2      2      2      2       1
# 380      2      2      2      2      2       1
# 381      2      2      2      2      2       1
# 382      2      2      2      2      2       1
# 383      2      2      2      2      2       1
# 384      2      2      2      2      2       1
# 385      2      2      2      2      2       1
# 386      2      2      2      2      2       1
# 387      2      2      2      2      2       1
# 388      2      2      2      2      2       1
# 389      2      2      2      2      2       1
# 390      2      2      2      2      2       1
# 391      2      2      2      2      2       1
# 392      2      2      2      2      2       1
# 393      2      2      2      2      2       1
# 394      0      2      2      2      2       1
# 395      0      2      2      2      2       1
# 396      1      2      2      2      2       1
# 397      1      2      2      2      2       1
# 398      1      2      2      2      2       1
# 399      1      2      2      2      2       1
#
# [400 rows x 15 columns]

# %% [markdown]
# We can now save the data:

# %%
data.to_csv("grid_aug_ex1.csv",index=False)
