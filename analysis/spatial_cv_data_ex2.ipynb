# %% [markdown]
# ## Setup
#
# Load required packages

# %%
import pandas as pd
import io
import requests
import numpy as np
import random
import libpysal
import pysal
# Out:
# C:\Users\kklemmer\AppData\Local\Continuum\anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# Read data

# %%
#Read from URL (Doesnt work for private repos)
#url="https://github.com/konstantinklemmer/spacegan/raw/master/data/synth_data.csv"
#s=requests.get(url).content
#data=pd.read_csv(io.StringIO(s.decode('utf-8')))

#Read from local file
data=pd.read_csv("./raw_data/synth_data_ex2.csv")

# %%
data.head(5)
# Out:
#    id         y         z  latitude  longitude
# 0   1 -0.111466  1.334913      1.75       1.75
# 1   2 -0.067598 -0.869272      1.75       5.25
# 2   3 -0.131009  0.055487      1.75       8.75
# 3   4 -0.054521  0.049067      1.75      12.25
# 4   5 -0.136375 -0.578356      1.75      15.75

# %% [markdown]
# Create a pairwise distance matrix (Euclidean) between the points

# %%
dist = pysal.lib.cg.distance_matrix(np.array(data[["longitude","latitude"]]))

# %% [markdown]
# Get the `k` smallest distances (of the whole matrix, since the points are equally distributed)

# %%
k=10
u_dist = np.unique(dist)
k_min_dist = np.sort(u_dist.flatten())[:k]

# %%
k_min_dist
# Out:
# array([ 0.        ,  3.5       ,  4.94974747,  7.        ,  7.82623792,
#         9.89949494, 10.5       , 11.06797181, 12.61942946, 14.        ])

# %% [markdown]
# Create spatial points object ([KDTree](https://pysal.readthedocs.io/en/dev/library/cg/kdtree.html))).

# %%
import pysal.lib
kd = pysal.lib.cg.kdtree.KDTree(np.array(data[["longitude","latitude"]]))

# %% [markdown]
# Compute spatial neighbourhoods weight matrix by distance threshold ("radius")

# %%
#wnn = pysal.lib.weights.KNN(kd, 8, ids=data["id"]) #KNN based weights
#wdist= pysal.lib.weights.distance.DistanceBand(kd, threshold=k_min_dist[1],binary=False,p=2) #Rook
wdist= pysal.lib.weights.distance.DistanceBand(kd, threshold=k_min_dist[2],binary=True,p=2) #Queen
#wdist= pysal.lib.weights.distance.DistanceBand(kd, threshold=k_min_dist[4],binary=True,p=2) #Queen 2nd degree

# %% [markdown]
# ## Spatial CV: Lat/Lon slicing

# %% [markdown]
# Create labels based on latitude / longitude binning and add the labels to the original data

# %%
data["lon_group"] = pd.cut(data["longitude"],bins=5,labels=[1,2,3,4,5])
data["lat_group"] = pd.cut(data["latitude"],bins=5,labels=[1,2,3,4,5])

# %% [markdown]
# This method loops over our lat/lon groups, keeping each group as test data and the rest as train data. However, as we want to do spatial cross-validation, we remove neighbors of the test set. This can help to prevent model overfitting. Here, we remove 1st and 2nd degree neighbors, but the method can be adapted as needed. We create 10 folds (5 lon, 5 lat slicing) and save these in the columns `lat_group[1-5]` and `lon_group[1-5]`. For the values in each of these columns, `1` indicates testing data, `2` training data and `0`indicates data to be removed.

# %%
for q in list(data)[-2::]: #Loop over the two slicing label columns 
    data["s_id"] = data[q] #Define which label column to use for slicing
    
    for j in np.unique(data["s_id"]): #Loop over the unique labels in the slicing column 
        
        data[q+str(j)] = 0
        
        test = data[data["s_id"]==j] #Define test data 
        data.loc[data["id"].isin(np.array(test["id"])),q+str(j)] = 1
        
        temp_id = [] #Create empty neighbourhood index
        
        for k in test.index: #Fill neighborhood index using first degree neighbors of test data
            temp_id = np.unique(np.concatenate([temp_id,wdist.neighbors[k]]).ravel().astype(np.int32))
            
        for l in temp_id: #Include second degree neighbors
            temp_id = np.unique(np.concatenate([temp_id,wdist.neighbors[l]]).ravel().astype(np.int32))
        
        #for m in temp_id: #Include third degree neighbors
        #    temp_id = np.unique(np.concatenate([temp_id,wdist.neighbors[m]]).ravel().astype(np.int32))
            
        train = data[data["s_id"]!=j] #Define train data 
        train = train.drop(temp_id,errors="ignore") #Exclude neighbors from index
        data.loc[data["id"].isin(np.array(train["id"])),q+str(j)] = 2
#Drop helper columns
data = data.drop(columns=["lon_group","lat_group","s_id"])

# %% [markdown]
# Rename columns to represent cross-validation folds

# %%
data.rename(columns=dict(zip(data.filter(regex='_group').columns,
                             ["fold1","fold2","fold3","fold4","fold5","fold6","fold7","fold8","fold9","fold10"])),
            inplace=True)

# %%
data
# Out:
#       id         y         z  latitude  longitude  fold1  fold2  fold3  fold4  \
# 0      1 -0.111466  1.334913      1.75       1.75      1      2      2      2
# 1      2 -0.067598 -0.869272      1.75       5.25      1      2      2      2
# 2      3 -0.131009  0.055487      1.75       8.75      1      2      2      2
# 3      4 -0.054521  0.049067      1.75      12.25      1      2      2      2
# 4      5 -0.136375 -0.578356      1.75      15.75      1      0      2      2
# 5      6 -0.058113 -0.998739      1.75      19.25      1      0      2      2
# 6      7 -0.120234 -0.002433      1.75      22.75      0      1      2      2
# 7      8 -0.085219  0.655512      1.75      26.25      0      1      2      2
# 8      9 -0.088057  1.476842      1.75      29.75      2      1      2      2
# 9     10 -0.110773 -1.909153      1.75      33.25      2      1      2      2
# 10    11 -0.061560 -0.702439      1.75      36.75      2      1      0      2
# 11    12 -0.129547 -0.311430      1.75      40.25      2      1      0      2
# 12    13 -0.049171 -1.663157      1.75      43.75      2      0      1      2
# 13    14 -0.137262 -0.750533      1.75      47.25      2      0      1      2
# 14    15 -0.061639 -0.777352      1.75      50.75      2      2      1      2
# 15    16 -0.117503 -0.722570      1.75      54.25      2      2      1      0
# 16    17 -0.085981 -2.188835      1.75      57.75      2      2      1      0
# 17    18 -0.085290  0.213419      1.75      61.25      2      2      0      1
# 18    19 -0.118042 -0.631923      1.75      64.75      2      2      0      1
# 19    20 -0.058677  1.520491      1.75      68.25      2      2      2      1
# 20    21 -0.134833  0.795956      1.75      71.75      2      2      2      1
# 21    22 -0.052609 -1.453530      1.75      75.25      2      2      2      1
# 22    23 -0.129909  0.098395      1.75      78.75      2      2      2      1
# 23    24 -0.063060 -0.593771      1.75      82.25      2      2      2      0
# 24    25 -0.113948  0.888281      1.75      85.75      2      2      2      0
# 25    26 -0.088737  0.053070      1.75      89.25      2      2      2      2
# 26    27 -0.086049 -0.557024      1.75      92.75      2      2      2      2
# 27    28 -0.115535  0.438397      1.75      96.25      2      2      2      2
# 28    29 -0.059298  0.152608      1.75      99.75      2      2      2      2
# 29    30  0.001633 -0.164618      5.25       1.75      1      2      2      2
# ..   ...       ...       ...       ...        ...    ...    ...    ...    ...
# 811  812  2.131963  0.905064     96.25      99.75      2      2      2      2
# 812  813  2.066796  0.328096     99.75       1.75      1      2      2      2
# 813  814 -2.139116  1.078090     99.75       5.25      1      2      2      2
# 814  815  2.364845 -0.060316     99.75       8.75      1      2      2      2
# 815  816 -2.072033 -0.243519     99.75      12.25      1      2      2      2
# 816  817  1.698019  2.241423     99.75      15.75      1      0      2      2
# 817  818 -0.815157 -2.035993     99.75      19.25      1      0      2      2
# 818  819  0.157500  0.390914     99.75      22.75      0      1      2      2
# 819  820  0.837479  0.384813     99.75      26.25      0      1      2      2
# 820  821 -1.603415  0.438696     99.75      29.75      2      1      2      2
# 821  822  2.310822  0.558141     99.75      33.25      2      1      2      2
# 822  823 -2.293671 -0.276406     99.75      36.75      2      1      0      2
# 823  824  2.295257  1.166288     99.75      40.25      2      1      0      2
# 824  825 -1.999505 -2.454277     99.75      43.75      2      0      1      2
# 825  826  1.524652 -0.805566     99.75      47.25      2      0      1      2
# 826  827 -0.533889 -0.119145     99.75      50.75      2      2      1      2
# 827  828 -0.218979  0.163216     99.75      54.25      2      2      1      0
# 828  829  0.993996  0.406480     99.75      57.75      2      2      1      0
# 829  830 -1.592417  0.639340     99.75      61.25      2      2      0      1
# 830  831  2.334380 -1.508518     99.75      64.75      2      2      0      1
# 831  832 -2.294347  0.007671     99.75      68.25      2      2      2      1
# 832  833  2.468208  0.524168     99.75      71.75      2      2      2      1
# 833  834 -1.771635  1.326336     99.75      75.25      2      2      2      1
# 834  835  1.344795 -0.113568     99.75      78.75      2      2      2      1
# 835  836 -0.407723  1.599149     99.75      82.25      2      2      2      0
# 836  837 -0.259081 -0.281528     99.75      85.75      2      2      2      0
# 837  838  1.341761 -0.049898     99.75      89.25      2      2      2      2
# 838  839 -1.542866  0.160214     99.75      92.75      2      2      2      2
# 839  840  2.342590 -0.502381     99.75      96.25      2      2      2      2
# 840  841 -2.137167  0.715938     99.75      99.75      2      2      2      2
#
#      fold5  fold6  fold7  fold8  fold9  fold10
# 0        2      1      2      2      2       2
# 1        2      1      2      2      2       2
# 2        2      1      2      2      2       2
# 3        2      1      2      2      2       2
# 4        2      1      2      2      2       2
# 5        2      1      2      2      2       2
# 6        2      1      2      2      2       2
# 7        2      1      2      2      2       2
# 8        2      1      2      2      2       2
# 9        2      1      2      2      2       2
# 10       2      1      2      2      2       2
# 11       2      1      2      2      2       2
# 12       2      1      2      2      2       2
# 13       2      1      2      2      2       2
# 14       2      1      2      2      2       2
# 15       2      1      2      2      2       2
# 16       2      1      2      2      2       2
# 17       2      1      2      2      2       2
# 18       2      1      2      2      2       2
# 19       2      1      2      2      2       2
# 20       2      1      2      2      2       2
# 21       0      1      2      2      2       2
# 22       0      1      2      2      2       2
# 23       1      1      2      2      2       2
# 24       1      1      2      2      2       2
# 25       1      1      2      2      2       2
# 26       1      1      2      2      2       2
# 27       1      1      2      2      2       2
# 28       1      1      2      2      2       2
# 29       2      1      2      2      2       2
# ..     ...    ...    ...    ...    ...     ...
# 811      1      2      2      2      2       1
# 812      2      2      2      2      2       1
# 813      2      2      2      2      2       1
# 814      2      2      2      2      2       1
# 815      2      2      2      2      2       1
# 816      2      2      2      2      2       1
# 817      2      2      2      2      2       1
# 818      2      2      2      2      2       1
# 819      2      2      2      2      2       1
# 820      2      2      2      2      2       1
# 821      2      2      2      2      2       1
# 822      2      2      2      2      2       1
# 823      2      2      2      2      2       1
# 824      2      2      2      2      2       1
# 825      2      2      2      2      2       1
# 826      2      2      2      2      2       1
# 827      2      2      2      2      2       1
# 828      2      2      2      2      2       1
# 829      2      2      2      2      2       1
# 830      2      2      2      2      2       1
# 831      2      2      2      2      2       1
# 832      2      2      2      2      2       1
# 833      0      2      2      2      2       1
# 834      0      2      2      2      2       1
# 835      1      2      2      2      2       1
# 836      1      2      2      2      2       1
# 837      1      2      2      2      2       1
# 838      1      2      2      2      2       1
# 839      1      2      2      2      2       1
# 840      1      2      2      2      2       1
#
# [841 rows x 15 columns]

# %% [markdown]
# We can now save the data:

# %%
data.to_csv("grid_aug_ex2.csv",index=False)
